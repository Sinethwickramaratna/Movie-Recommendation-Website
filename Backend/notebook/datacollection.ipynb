# %%
import requests
import time
import requests.exceptions as RequestException
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("TMDB_API_KEY")
BASE_URL = "https://api.themoviedb.org/3"

def get_movie_ids(start_page=1, end_page=501):

  all_ids = []

  for page in range(start_page, end_page):
    try:
      url = f"{BASE_URL}/discover/movie"
      params = {
        "api_key": API_KEY,
        "language": "en-US",
        "sort": "popularity.desc",
        "page": page
      }

      response = requests.get(url, params=params)

      if response.status_code != 200:
        print(f"Page {page} returned {response.status_code}. Stopping.")
        break
      data = response.json()

      if "results" not in data:
        print(f"No results key on page {page}")
        print(data)
        break

      ids = [movie["id"] for movie in data["results"]]
      all_ids.extend(ids)

      print(f"Collected page {page}")
      time.sleep(0.25)  # To respect API rate limits

      id_series = pd.DataFrame({"id": list(range(len(all_ids))), "Movie_id": all_ids})
      id_series.to_csv("../data/movie_ids.csv", index=False)

      print(f"Total IDs collected so far: {len(all_ids)}")
    
    except RequestException as e:
      print(f"Error fetching page {page}: {e}")
      print("Stopping program")
      break

  return len(all_ids)

# %%
if __name__ == "__main__":
    total = get_movie_ids()
    print(f"Final total IDs collected: {total}")
# Out:
# Collected page 1
# Total IDs collected so far: 20
# Collected page 2
# Total IDs collected so far: 40
# Collected page 3
# Total IDs collected so far: 60
# Collected page 4
# Total IDs collected so far: 80
# Collected page 5
# Total IDs collected so far: 100
# Collected page 6
# Total IDs collected so far: 120
# Collected page 7
# Total IDs collected so far: 140
# Collected page 8
# Total IDs collected so far: 160
# Collected page 9
# Total IDs collected so far: 180
# Collected page 10
# Total IDs collected so far: 200
# Collected page 11
# Total IDs collected so far: 220
# Collected page 12
# Total IDs collected so far: 240
# Collected page 13
# Total IDs collected so far: 260
# Collected page 14
# Total IDs collected so far: 280
# Collected page 15
# Total IDs collected so far: 300
# Collected page 16
# Total IDs collected so far: 320
# Collected page 17
# Total IDs collected so far: 340
# Collected page 18
# Total IDs collected so far: 360
# Collected page 19
# Total IDs collected so far: 380
# Collected page 20
# Total IDs collected so far: 400
# Collected page 21
# Total IDs collected so far: 420
# Collected page 22
# Total IDs collected so far: 440
# Collected page 23
# Total IDs collected so far: 460
# Collected page 24
# Total IDs collected so far: 480
# Collected page 25
# Total IDs collected so far: 500
# Collected page 26
# Total IDs collected so far: 520
# Collected page 27
# Total IDs collected so far: 540
# Collected page 28
# Total IDs collected so far: 560
# Collected page 29
# Total IDs collected so far: 580
# Collected page 30
# Total IDs collected so far: 600
# Collected page 31
# Total IDs collected so far: 620
# Collected page 32
# Total IDs collected so far: 640
# Collected page 33
# Total IDs collected so far: 660
# Collected page 34
# Total IDs collected so far: 680
# Collected page 35
# Total IDs collected so far: 700
# Collected page 36
# Total IDs collected so far: 720
# Collected page 37
# Total IDs collected so far: 740
# Collected page 38
# Total IDs collected so far: 760
# Collected page 39
# Total IDs collected so far: 780
# Collected page 40
# Total IDs collected so far: 800
# Collected page 41
# Total IDs collected so far: 820
# Collected page 42
# Total IDs collected so far: 840
# Collected page 43
# Total IDs collected so far: 860
# Collected page 44
# Total IDs collected so far: 880
# Collected page 45
# Total IDs collected so far: 900
# Collected page 46
# Total IDs collected so far: 920
# Collected page 47
# Total IDs collected so far: 940
# Collected page 48
# Total IDs collected so far: 960
# Collected page 49
# Total IDs collected so far: 980
# Collected page 50
# Total IDs collected so far: 1000
# Collected page 51
# Total IDs collected so far: 1020
# Collected page 52
# Total IDs collected so far: 1040
# Collected page 53
# Total IDs collected so far: 1060
# Collected page 54
# Total IDs collected so far: 1080
# Collected page 55
# Total IDs collected so far: 1100
# Collected page 56
# Total IDs collected so far: 1120
# Collected page 57
# Total IDs collected so far: 1140
# Collected page 58
# Total IDs collected so far: 1160
# Collected page 59
# Total IDs collected so far: 1180
# Collected page 60
# Total IDs collected so far: 1200
# Collected page 61
# Total IDs collected so far: 1220
# Collected page 62
# Total IDs collected so far: 1240
# Collected page 63
# Total IDs collected so far: 1260
# Collected page 64
# Total IDs collected so far: 1280
# Collected page 65
# Total IDs collected so far: 1300
# Collected page 66
# Total IDs collected so far: 1320
# Collected page 67
# Total IDs collected so far: 1340
# Collected page 68
# Total IDs collected so far: 1360
# Collected page 69
# Total IDs collected so far: 1380
# Collected page 70
# Total IDs collected so far: 1400
# Collected page 71
# Total IDs collected so far: 1420
# Collected page 72
# Total IDs collected so far: 1440
# Collected page 73
# Total IDs collected so far: 1460
# Collected page 74
# Total IDs collected so far: 1480
# Collected page 75
# Total IDs collected so far: 1500
# Collected page 76
# Total IDs collected so far: 1520
# Collected page 77
# Total IDs collected so far: 1540
# Collected page 78
# Total IDs collected so far: 1560
# Collected page 79
# Total IDs collected so far: 1580
# Collected page 80
# Total IDs collected so far: 1600
# Collected page 81
# Total IDs collected so far: 1620
# Collected page 82
# Total IDs collected so far: 1640
# Collected page 83
# Total IDs collected so far: 1660
# Collected page 84
# Total IDs collected so far: 1680
# Collected page 85
# Total IDs collected so far: 1700
# Collected page 86
# Total IDs collected so far: 1720
# Collected page 87
# Total IDs collected so far: 1740
# Collected page 88
# Total IDs collected so far: 1760
# Collected page 89
# Total IDs collected so far: 1780
# Collected page 90
# Total IDs collected so far: 1800
# Collected page 91
# Total IDs collected so far: 1820
# Collected page 92
# Total IDs collected so far: 1840
# Collected page 93
# Total IDs collected so far: 1860
# Collected page 94
# Total IDs collected so far: 1880
# Collected page 95
# Total IDs collected so far: 1900
# Collected page 96
# Total IDs collected so far: 1920
# Collected page 97
# Total IDs collected so far: 1940
# Collected page 98
# Total IDs collected so far: 1960
# Collected page 99
# Total IDs collected so far: 1980
# Collected page 100
# Total IDs collected so far: 2000
# Collected page 101
# Total IDs collected so far: 2020
# Collected page 102
# Total IDs collected so far: 2040
# Collected page 103
# Total IDs collected so far: 2060
# Collected page 104
# Total IDs collected so far: 2080
# Collected page 105
# Total IDs collected so far: 2100
# Collected page 106
# Total IDs collected so far: 2120
# Collected page 107
# Total IDs collected so far: 2140
# Collected page 108
# Total IDs collected so far: 2160
# Collected page 109
# Total IDs collected so far: 2180
# Collected page 110
# Total IDs collected so far: 2200
# Collected page 111
# Total IDs collected so far: 2220
# Collected page 112
# Total IDs collected so far: 2240
# Collected page 113
# Total IDs collected so far: 2260
# Collected page 114
# Total IDs collected so far: 2280
# Collected page 115
# Total IDs collected so far: 2300
# Collected page 116
# Total IDs collected so far: 2320
# Collected page 117
# Total IDs collected so far: 2340
# Collected page 118
# Total IDs collected so far: 2360
# Collected page 119
# Total IDs collected so far: 2380
# Collected page 120
# Total IDs collected so far: 2400
# Collected page 121
# Total IDs collected so far: 2420
# Collected page 122
# Total IDs collected so far: 2440
# Collected page 123
# Total IDs collected so far: 2460
# Collected page 124
# Total IDs collected so far: 2480
# Collected page 125
# Total IDs collected so far: 2500
# Collected page 126
# Total IDs collected so far: 2520
# Collected page 127
# Total IDs collected so far: 2540
# Collected page 128
# Total IDs collected so far: 2560
# Collected page 129
# Total IDs collected so far: 2580
# Collected page 130
# Total IDs collected so far: 2600
# Collected page 131
# Total IDs collected so far: 2620
# Collected page 132
# Total IDs collected so far: 2640
# Collected page 133
# Total IDs collected so far: 2660
# Collected page 134
# Total IDs collected so far: 2680
# Collected page 135
# Total IDs collected so far: 2700
# Collected page 136
# Total IDs collected so far: 2720
# Collected page 137
# Total IDs collected so far: 2740
# Collected page 138
# Total IDs collected so far: 2760
# Collected page 139
# Total IDs collected so far: 2780
# Collected page 140
# Total IDs collected so far: 2800
# Collected page 141
# Total IDs collected so far: 2820
# Collected page 142
# Total IDs collected so far: 2840
# Collected page 143
# Total IDs collected so far: 2860
# Collected page 144
# Total IDs collected so far: 2880
# Collected page 145
# Total IDs collected so far: 2900
# Collected page 146
# Total IDs collected so far: 2920
# Collected page 147
# Total IDs collected so far: 2940
# Collected page 148
# Total IDs collected so far: 2960
# Collected page 149
# Total IDs collected so far: 2980
# Collected page 150
# Total IDs collected so far: 3000
# Collected page 151
# Total IDs collected so far: 3020
# Collected page 152
# Total IDs collected so far: 3040
# Collected page 153
# Total IDs collected so far: 3060
# Collected page 154
# Total IDs collected so far: 3080
# Collected page 155
# Total IDs collected so far: 3100
# Collected page 156
# Total IDs collected so far: 3120
# Collected page 157
# Total IDs collected so far: 3140
# Collected page 158
# Total IDs collected so far: 3160
# Collected page 159
# Total IDs collected so far: 3180
# Collected page 160
# Total IDs collected so far: 3200
# Collected page 161
# Total IDs collected so far: 3220
# Collected page 162
# Total IDs collected so far: 3240
# Collected page 163
# Total IDs collected so far: 3260
# Collected page 164
# Total IDs collected so far: 3280
# Collected page 165
# Total IDs collected so far: 3300
# Collected page 166
# Total IDs collected so far: 3320
# Collected page 167
# Total IDs collected so far: 3340
# Collected page 168
# Total IDs collected so far: 3360
# Collected page 169
# Total IDs collected so far: 3380
# Collected page 170
# Total IDs collected so far: 3400
# Collected page 171
# Total IDs collected so far: 3420
# Collected page 172
# Total IDs collected so far: 3440
# Collected page 173
# Total IDs collected so far: 3460
# Collected page 174
# Total IDs collected so far: 3480
# Collected page 175
# Total IDs collected so far: 3500
# Collected page 176
# Total IDs collected so far: 3520
# Collected page 177
# Total IDs collected so far: 3540
# Collected page 178
# Total IDs collected so far: 3560
# Collected page 179
# Total IDs collected so far: 3580
# Collected page 180
# Total IDs collected so far: 3600
# Collected page 181
# Total IDs collected so far: 3620
# Collected page 182
# Total IDs collected so far: 3640
# Collected page 183
# Total IDs collected so far: 3660
# Collected page 184
# Total IDs collected so far: 3680
# Collected page 185
# Total IDs collected so far: 3700
# Collected page 186
# Total IDs collected so far: 3720
# Collected page 187
# Total IDs collected so far: 3740
# Collected page 188
# Total IDs collected so far: 3760
# Collected page 189
# Total IDs collected so far: 3780
# Collected page 190
# Total IDs collected so far: 3800
# Collected page 191
# Total IDs collected so far: 3820
# Collected page 192
# Total IDs collected so far: 3840
# Collected page 193
# Total IDs collected so far: 3860
# Collected page 194
# Total IDs collected so far: 3880
# Collected page 195
# Total IDs collected so far: 3900
# Collected page 196
# Total IDs collected so far: 3920
# Collected page 197
# Total IDs collected so far: 3940
# Collected page 198
# Total IDs collected so far: 3960
# Collected page 199
# Total IDs collected so far: 3980
# Collected page 200
# Total IDs collected so far: 4000
# Collected page 201
# Total IDs collected so far: 4020
# Collected page 202
# Total IDs collected so far: 4040
# Collected page 203
# Total IDs collected so far: 4060
# Collected page 204
# Total IDs collected so far: 4080
# Collected page 205
# Total IDs collected so far: 4100
# Collected page 206
# Total IDs collected so far: 4120
# Collected page 207
# Total IDs collected so far: 4140
# Collected page 208
# Total IDs collected so far: 4160
# Collected page 209
# Total IDs collected so far: 4180
# Collected page 210
# Total IDs collected so far: 4200
# Collected page 211
# Total IDs collected so far: 4220
# Collected page 212
# Total IDs collected so far: 4240
# Collected page 213
# Total IDs collected so far: 4260
# Collected page 214
# Total IDs collected so far: 4280
# Collected page 215
# Total IDs collected so far: 4300
# Collected page 216
# Total IDs collected so far: 4320
# Collected page 217
# Total IDs collected so far: 4340
# Collected page 218
# Total IDs collected so far: 4360
# Collected page 219
# Total IDs collected so far: 4380
# Collected page 220
# Total IDs collected so far: 4400
# Collected page 221
# Total IDs collected so far: 4420
# Collected page 222
# Total IDs collected so far: 4440
# Collected page 223
# Total IDs collected so far: 4460
# Collected page 224
# Total IDs collected so far: 4480
# Collected page 225
# Total IDs collected so far: 4500
# Collected page 226
# Total IDs collected so far: 4520
# Collected page 227
# Total IDs collected so far: 4540
# Collected page 228
# Total IDs collected so far: 4560
# Collected page 229
# Total IDs collected so far: 4580
# Collected page 230
# Total IDs collected so far: 4600
# Collected page 231
# Total IDs collected so far: 4620
# Collected page 232
# Total IDs collected so far: 4640
# Collected page 233
# Total IDs collected so far: 4660
# Collected page 234
# Total IDs collected so far: 4680
# Collected page 235
# Total IDs collected so far: 4700
# Collected page 236
# Total IDs collected so far: 4720
# Collected page 237
# Total IDs collected so far: 4740
# Collected page 238
# Total IDs collected so far: 4760
# Collected page 239
# Total IDs collected so far: 4780
# Collected page 240
# Total IDs collected so far: 4800
# Collected page 241
# Total IDs collected so far: 4820
# Collected page 242
# Total IDs collected so far: 4840
# Collected page 243
# Total IDs collected so far: 4860
# Collected page 244
# Total IDs collected so far: 4880
# Collected page 245
# Total IDs collected so far: 4900
# Collected page 246
# Total IDs collected so far: 4920
# Collected page 247
# Total IDs collected so far: 4940
# Collected page 248
# Total IDs collected so far: 4960
# Collected page 249
# Total IDs collected so far: 4980
# Collected page 250
# Total IDs collected so far: 5000
# Collected page 251
# Total IDs collected so far: 5020
# Collected page 252
# Total IDs collected so far: 5040
# Collected page 253
# Total IDs collected so far: 5060
# Collected page 254
# Total IDs collected so far: 5080
# Collected page 255
# Total IDs collected so far: 5100
# Collected page 256
# Total IDs collected so far: 5120
# Collected page 257
# Total IDs collected so far: 5140
# Collected page 258
# Total IDs collected so far: 5160
# Collected page 259
# Total IDs collected so far: 5180
# Collected page 260
# Total IDs collected so far: 5200
# Collected page 261
# Total IDs collected so far: 5220
# Collected page 262
# Total IDs collected so far: 5240
# Collected page 263
# Total IDs collected so far: 5260
# Collected page 264
# Total IDs collected so far: 5280
# Collected page 265
# Total IDs collected so far: 5300
# Collected page 266
# Total IDs collected so far: 5320
# Collected page 267
# Total IDs collected so far: 5340
# Collected page 268
# Total IDs collected so far: 5360
# Collected page 269
# Total IDs collected so far: 5380
# Collected page 270
# Total IDs collected so far: 5400
# Collected page 271
# Total IDs collected so far: 5420
# Collected page 272
# Total IDs collected so far: 5440
# Collected page 273
# Total IDs collected so far: 5460
# Collected page 274
# Total IDs collected so far: 5480
# Collected page 275
# Total IDs collected so far: 5500
# Collected page 276
# Total IDs collected so far: 5520
# Collected page 277
# Total IDs collected so far: 5540
# Collected page 278
# Total IDs collected so far: 5560
# Collected page 279
# Total IDs collected so far: 5580
# Collected page 280
# Total IDs collected so far: 5600
# Collected page 281
# Total IDs collected so far: 5620
# Collected page 282
# Total IDs collected so far: 5640
# Collected page 283
# Total IDs collected so far: 5660
# Collected page 284
# Total IDs collected so far: 5680
# Collected page 285
# Total IDs collected so far: 5700
# Collected page 286
# Total IDs collected so far: 5720
# Collected page 287
# Total IDs collected so far: 5740
# Collected page 288
# Total IDs collected so far: 5760
# Collected page 289
# Total IDs collected so far: 5780
# Collected page 290
# Total IDs collected so far: 5800
# Collected page 291
# Total IDs collected so far: 5820
# Collected page 292
# Total IDs collected so far: 5840
# Collected page 293
# Total IDs collected so far: 5860
# Collected page 294
# Total IDs collected so far: 5880
# Collected page 295
# Total IDs collected so far: 5900
# Collected page 296
# Total IDs collected so far: 5920
# Collected page 297
# Total IDs collected so far: 5940
# Collected page 298
# Total IDs collected so far: 5960
# Collected page 299
# Total IDs collected so far: 5980
# Collected page 300
# Total IDs collected so far: 6000
# Collected page 301
# Total IDs collected so far: 6020
# Collected page 302
# Total IDs collected so far: 6040
# Collected page 303
# Total IDs collected so far: 6060
# Collected page 304
# Total IDs collected so far: 6080
# Collected page 305
# Total IDs collected so far: 6100
# Collected page 306
# Total IDs collected so far: 6120
# Collected page 307
# Total IDs collected so far: 6140
# Collected page 308
# Total IDs collected so far: 6160
# Collected page 309
# Total IDs collected so far: 6180
# Collected page 310
# Total IDs collected so far: 6200
# Collected page 311
# Total IDs collected so far: 6220
# Collected page 312
# Total IDs collected so far: 6240
# Collected page 313
# Total IDs collected so far: 6260
# Collected page 314
# Total IDs collected so far: 6280
# Collected page 315
# Total IDs collected so far: 6300
# Collected page 316
# Total IDs collected so far: 6320
# Collected page 317
# Total IDs collected so far: 6340
# Collected page 318
# Total IDs collected so far: 6360
# Collected page 319
# Total IDs collected so far: 6380
# Collected page 320
# Total IDs collected so far: 6400
# Collected page 321
# Total IDs collected so far: 6420
# Collected page 322
# Total IDs collected so far: 6440
# Collected page 323
# Total IDs collected so far: 6460
# Collected page 324
# Total IDs collected so far: 6480
# Collected page 325
# Total IDs collected so far: 6500
# Collected page 326
# Total IDs collected so far: 6520
# Collected page 327
# Total IDs collected so far: 6540
# Collected page 328
# Total IDs collected so far: 6560
# Collected page 329
# Total IDs collected so far: 6580
# Collected page 330
# Total IDs collected so far: 6600
# Collected page 331
# Total IDs collected so far: 6620
# Collected page 332
# Total IDs collected so far: 6640
# Collected page 333
# Total IDs collected so far: 6660
# Collected page 334
# Total IDs collected so far: 6680
# Collected page 335
# Total IDs collected so far: 6700
# Collected page 336
# Total IDs collected so far: 6720
# Collected page 337
# Total IDs collected so far: 6740
# Collected page 338
# Total IDs collected so far: 6760
# Collected page 339
# Total IDs collected so far: 6780
# Collected page 340
# Total IDs collected so far: 6800
# Collected page 341
# Total IDs collected so far: 6820
# Collected page 342
# Total IDs collected so far: 6840
# Collected page 343
# Total IDs collected so far: 6860
# Collected page 344
# Total IDs collected so far: 6880
# Collected page 345
# Total IDs collected so far: 6900
# Collected page 346
# Total IDs collected so far: 6920
# Collected page 347
# Total IDs collected so far: 6940
# Collected page 348
# Total IDs collected so far: 6960
# Collected page 349
# Total IDs collected so far: 6980
# Collected page 350
# Total IDs collected so far: 7000
# Collected page 351
# Total IDs collected so far: 7020
# Collected page 352
# Total IDs collected so far: 7040
# Collected page 353
# Total IDs collected so far: 7060
# Collected page 354
# Total IDs collected so far: 7080
# Collected page 355
# Total IDs collected so far: 7100
# Collected page 356
# Total IDs collected so far: 7120
# Collected page 357
# Total IDs collected so far: 7140
# Collected page 358
# Total IDs collected so far: 7160
# Collected page 359
# Total IDs collected so far: 7180
# Collected page 360
# Total IDs collected so far: 7200
# Collected page 361
# Total IDs collected so far: 7220
# Collected page 362
# Total IDs collected so far: 7240
# Collected page 363
# Total IDs collected so far: 7260
# Collected page 364
# Total IDs collected so far: 7280
# Collected page 365
# Total IDs collected so far: 7300
# Collected page 366
# Total IDs collected so far: 7320
# Collected page 367
# Total IDs collected so far: 7340
# Collected page 368
# Total IDs collected so far: 7360
# Collected page 369
# Total IDs collected so far: 7380
# Collected page 370
# Total IDs collected so far: 7400
# Collected page 371
# Total IDs collected so far: 7420
# Collected page 372
# Total IDs collected so far: 7440
# Collected page 373
# Total IDs collected so far: 7460
# Collected page 374
# Total IDs collected so far: 7480
# Collected page 375
# Total IDs collected so far: 7500
# Collected page 376
# Total IDs collected so far: 7520
# Collected page 377
# Total IDs collected so far: 7540
# Collected page 378
# Total IDs collected so far: 7560
# Collected page 379
# Total IDs collected so far: 7580
# Collected page 380
# Total IDs collected so far: 7600
# Collected page 381
# Total IDs collected so far: 7620
# Collected page 382
# Total IDs collected so far: 7640
# Collected page 383
# Total IDs collected so far: 7660
# Collected page 384
# Total IDs collected so far: 7680
# Collected page 385
# Total IDs collected so far: 7700
# Collected page 386
# Total IDs collected so far: 7720
# Collected page 387
# Total IDs collected so far: 7740
# Collected page 388
# Total IDs collected so far: 7760
# Collected page 389
# Total IDs collected so far: 7780
# Collected page 390
# Total IDs collected so far: 7800
# Collected page 391
# Total IDs collected so far: 7820
# Collected page 392
# Total IDs collected so far: 7840
# Collected page 393
# Total IDs collected so far: 7860
# Collected page 394
# Total IDs collected so far: 7880
# Collected page 395
# Total IDs collected so far: 7900
# Collected page 396
# Total IDs collected so far: 7920
# Collected page 397
# Total IDs collected so far: 7940
# Collected page 398
# Total IDs collected so far: 7960
# Collected page 399
# Total IDs collected so far: 7980
# Collected page 400
# Total IDs collected so far: 8000
# Collected page 401
# Total IDs collected so far: 8020
# Collected page 402
# Total IDs collected so far: 8040
# Collected page 403
# Total IDs collected so far: 8060
# Collected page 404
# Total IDs collected so far: 8080
# Collected page 405
# Total IDs collected so far: 8100
# Collected page 406
# Total IDs collected so far: 8120
# Collected page 407
# Total IDs collected so far: 8140
# Collected page 408
# Total IDs collected so far: 8160
# Collected page 409
# Total IDs collected so far: 8180
# Collected page 410
# Total IDs collected so far: 8200
# Collected page 411
# Total IDs collected so far: 8220
# Collected page 412
# Total IDs collected so far: 8240
# Collected page 413
# Total IDs collected so far: 8260
# Collected page 414
# Total IDs collected so far: 8280
# Collected page 415
# Total IDs collected so far: 8300
# Collected page 416
# Total IDs collected so far: 8320
# Collected page 417
# Total IDs collected so far: 8340
# Collected page 418
# Total IDs collected so far: 8360
# Collected page 419
# Total IDs collected so far: 8380
# Collected page 420
# Total IDs collected so far: 8400
# Collected page 421
# Total IDs collected so far: 8420
# Collected page 422
# Total IDs collected so far: 8440
# Collected page 423
# Total IDs collected so far: 8460
# Collected page 424
# Total IDs collected so far: 8480
# Collected page 425
# Total IDs collected so far: 8500
# Collected page 426
# Total IDs collected so far: 8520
# Collected page 427
# Total IDs collected so far: 8540
# Collected page 428
# Total IDs collected so far: 8560
# Collected page 429
# Total IDs collected so far: 8580
# Collected page 430
# Total IDs collected so far: 8600
# Collected page 431
# Total IDs collected so far: 8620
# Collected page 432
# Total IDs collected so far: 8640
# Collected page 433
# Total IDs collected so far: 8660
# Collected page 434
# Total IDs collected so far: 8680
# Collected page 435
# Total IDs collected so far: 8700
# Collected page 436
# Total IDs collected so far: 8720
# Collected page 437
# Total IDs collected so far: 8740
# Collected page 438
# Total IDs collected so far: 8760
# Collected page 439
# Total IDs collected so far: 8780
# Collected page 440
# Total IDs collected so far: 8800
# Collected page 441
# Total IDs collected so far: 8820
# Collected page 442
# Total IDs collected so far: 8840
# Collected page 443
# Total IDs collected so far: 8860
# Collected page 444
# Total IDs collected so far: 8880
# Collected page 445
# Total IDs collected so far: 8900
# Collected page 446
# Total IDs collected so far: 8920
# Collected page 447
# Total IDs collected so far: 8940
# Collected page 448
# Total IDs collected so far: 8960
# Collected page 449
# Total IDs collected so far: 8980
# Collected page 450
# Total IDs collected so far: 9000
# Collected page 451
# Total IDs collected so far: 9020
# Collected page 452
# Total IDs collected so far: 9040
# Collected page 453
# Total IDs collected so far: 9060
# Collected page 454
# Total IDs collected so far: 9080
# Collected page 455
# Total IDs collected so far: 9100
# Collected page 456
# Total IDs collected so far: 9120
# Collected page 457
# Total IDs collected so far: 9140
# Collected page 458
# Total IDs collected so far: 9160
# Collected page 459
# Total IDs collected so far: 9180
# Collected page 460
# Total IDs collected so far: 9200
# Collected page 461
# Total IDs collected so far: 9220
# Collected page 462
# Total IDs collected so far: 9240
# Collected page 463
# Total IDs collected so far: 9260
# Collected page 464
# Total IDs collected so far: 9280
# Collected page 465
# Total IDs collected so far: 9300
# Collected page 466
# Total IDs collected so far: 9320
# Collected page 467
# Total IDs collected so far: 9340
# Collected page 468
# Total IDs collected so far: 9360
# Collected page 469
# Total IDs collected so far: 9380
# Collected page 470
# Total IDs collected so far: 9400
# Collected page 471
# Total IDs collected so far: 9420
# Collected page 472
# Total IDs collected so far: 9440
# Collected page 473
# Total IDs collected so far: 9460
# Collected page 474
# Total IDs collected so far: 9480
# Collected page 475
# Total IDs collected so far: 9500
# Collected page 476
# Total IDs collected so far: 9520
# Collected page 477
# Total IDs collected so far: 9540
# Collected page 478
# Total IDs collected so far: 9560
# Collected page 479
# Total IDs collected so far: 9580
# Collected page 480
# Total IDs collected so far: 9600
# Collected page 481
# Total IDs collected so far: 9620
# Collected page 482
# Total IDs collected so far: 9640
# Collected page 483
# Total IDs collected so far: 9660
# Collected page 484
# Total IDs collected so far: 9680
# Collected page 485
# Total IDs collected so far: 9700
# Collected page 486
# Total IDs collected so far: 9720
# Collected page 487
# Total IDs collected so far: 9740
# Collected page 488
# Total IDs collected so far: 9760
# Collected page 489
# Total IDs collected so far: 9780
# Collected page 490
# Total IDs collected so far: 9800
# Collected page 491
# Total IDs collected so far: 9820
# Collected page 492
# Total IDs collected so far: 9840
# Collected page 493
# Total IDs collected so far: 9860
# Collected page 494
# Total IDs collected so far: 9880
# Collected page 495
# Total IDs collected so far: 9900
# Collected page 496
# Total IDs collected so far: 9920
# Collected page 497
# Total IDs collected so far: 9940
# Collected page 498
# Total IDs collected so far: 9960
# Collected page 499
# Total IDs collected so far: 9980
# Collected page 500
# Total IDs collected so far: 10000
# Final total IDs collected: 10000
